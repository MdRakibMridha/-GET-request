# %% [markdown]
# CityBikes API Documentation link: https://api.citybik.es/v2/

# %% [markdown]
# **01.Import libraries**

# %%
#loading the pages
import requests
import json

# %% [markdown]
# **02.Sending get request!**

# %%
#define the url
url = 'http://api.citybik.es/v2/networks'

# %%
# we can make a get request to this API endpoint with request.get
response = requests.get(url)
# this method returns the response from the server
# we store this response in a variable for future processing

# %% [markdown]
# **03.Investigating the response**

# %%
#checking the status code of the response
response.status_code
# Out:
# 200

# %%
# Inspecting the content body of the response (as a regular 'string')
response.text

# %% [markdown]
# **04.Handling the JSON**

# %%
# request has in-build method to directly convert the response to JSON format
response.json()

# %%
#cheking the type of json file
type(response.json())
# Out:
# dict

# %%
#.dumps() has options to make the string 'prettier', more readable
#we can nchoose the number of spaces to be used as indentation
json_data = json.dumps(response.json(), indent=4)

# %%
#stored response.json() with a variable named data_json to check the structure of the json data
data_json = response.json()

# %%
# checking the number of keys
data_json.keys()
# Out:
# dict_keys(['networks'])

# %%
# negigating the specific keys using indexing
data_json['networks'][52]
# Out:
# {'company': 'Empresa Municipal de Transportes de Madrid, S.A.',
#  'href': '/v2/networks/bicimad',
#  'id': 'bicimad',
#  'location': {'city': 'Madrid',
#   'country': 'ES',
#   'latitude': 40.4168,
#   'longitude': -3.7038},
#  'name': 'BiciMAD'}

# %% [markdown]
# **05.Pagination**

# %%
networks = []
                                       # using 2nd for loop for PAGINATION
url = 'http://api.citybik.es/v2/networks'
response = requests.get(url)
data_json = response.json()

for bikes in range(len(data_json['networks'])):           # using 1st for loop for each networks
      com = data_json['networks'][bikes]['company']
      ID = data_json['networks'][bikes]['id']
      Loc = data_json['networks'][bikes]['location']['city']
      nam = data_json['networks'][bikes]['name']

      dct = {
          'name'       : nam,
          'id'         : ID, 
          'company'    : com,       
          'location'   : Loc   
      }
      networks.append(dct)

# %%
#checking the ranging
for page in range(1,11):
  url = f'http://api.citybik.es/v2/networks?page={page}'
  print(url)
# Out:
# http://api.citybik.es/v2/networks?page=1
# http://api.citybik.es/v2/networks?page=2
# http://api.citybik.es/v2/networks?page=3
# http://api.citybik.es/v2/networks?page=4
# http://api.citybik.es/v2/networks?page=5
# http://api.citybik.es/v2/networks?page=6
# http://api.citybik.es/v2/networks?page=7
# http://api.citybik.es/v2/networks?page=8
# http://api.citybik.es/v2/networks?page=9
# http://api.citybik.es/v2/networks?page=10

# %%
networks
# Out:
# [{'name': 'Velobike',
#   'id': 'velobike-moscow',
#   'company': ['ЗАО «СитиБайк»'],
#   'location': 'Moscow'},
#  {'name': 'Bysykkel',
#   'id': 'baerum-bysykkel',
#   'company': ['Urban Infrastructure Partner'],
#   'location': 'Bærum'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-siena',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Siena'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-maroussi',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Maroussi'},
#  {'name': 'Cycle Hire',
#   'id': 'cycle-hire-slough',
#   'company': ['Groundwork', 'Slough Borough Council', 'ITS'],
#   'location': 'Slough'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-nafplio',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Maroussi'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-parco-dei-colli-di-bergamo',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Parco dei Colli di Bergamo'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-aigialeia',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Maroussi'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-marathon',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Marathon'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-mantova',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Mantova'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-neasmyrni',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Νea Smyrni'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-moschatotavros',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Μoschato-Tavros'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-arxaiaolympia',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Αrxaia Olympia'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-kiato',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Kιato'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-assemini',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Assemini'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-rhodes',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Rhodes'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-florina',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Florina'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-tortoli',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Tortolì'},
#  {'name': 'Cyclopolis',
#   'id': 'cyclopolis-limnos',
#   'company': ['Cyclopolis Systems'],
#   'location': 'Limnos'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-gaeta',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Gaeta'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-borgarello',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Borgarello'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-pizzighettone-formigara',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Pizzighettone e Formigara'},
#  {'name': 'Coca-Cola Zero® Bikes',
#   'id': 'cork',
#   'company': ['The National Transport Authority'],
#   'location': 'Cork'},
#  {'name': 'Coca-Cola Zero® Bikes',
#   'id': 'limerick',
#   'company': ['The National Transport Authority'],
#   'location': 'Limerick'},
#  {'name': 'Pun Pun Bike Share',
#   'id': 'punpunbikeshare',
#   'company': ['BTS Group Holdings'],
#   'location': 'Bangkok'},
#  {'name': 'Coca-Cola Zero® Bikes',
#   'id': 'galway',
#   'company': ['The National Transport Authority'],
#   'location': 'Galway'},
#  {'name': 'BBBike',
#   'id': 'bbbike',
#   'company': ['Bike U Sp. z o.o.'],
#   'location': 'Bielsko-Biała'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-montecatini-terme',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Montecatini Terme'},
#  {'name': 'Bydgoski rower aglomeracyjny',
#   'id': 'bikeu-bra',
#   'company': ['Bike U Sp. z o.o.'],
#   'location': 'Bydgoszcz'},
#  {'name': 'Santander Cycles',
#   'id': 'santander-cycles',
#   'company': ['PBSC', 'Serco Group plc'],
#   'location': 'London'},
#  {'name': 'WE-cycle',
#   'id': 'we-cycle',
#   'company': ['PBSC', 'Alta Bicycle Share, Inc'],
#   'location': 'Aspen, CO'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-carrara',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Carrara'},
#  {'name': 'WOW Citybike',
#   'id': 'wowcycle-reykjavik',
#   'company': ['PBSC', 'Alta Bicycle Share, Inc'],
#   'location': 'Reykjavík'},
#  {'name': "StadtRAD Hamburg'",
#   'id': 'stadtrad-hamburg',
#   'company': ['Transparenzportal Hamburg'],
#   'location': 'Hamburg'},
#  {'name': 'Tigullionbike',
#   'id': 'tigullionbike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Sestri Levante - Lavagna'},
#  {'name': 'ARbike',
#   'id': 'arbike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Arezzo'},
#  {'name': 'Velobike',
#   'id': 'velobike',
#   'company': ['Velobike.kz, LLP', 'Smoove'],
#   'location': 'Astana'},
#  {'name': "Velib' Métropôle",
#   'id': 'velib',
#   'company': None,
#   'location': 'Paris'},
#  {'name': 'Ascoli Piceno',
#   'id': 'ascoli-piceno',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Ascoli Piceno'},
#  {'name': 'BiGi',
#   'id': 'bigi',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Bergamo'},
#  {'name': 'Girocleta',
#   'id': 'girocleta',
#   'company': ['ICNITA S.L.'],
#   'location': 'Girona'},
#  {'name': 'Alba',
#   'id': 'alba',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Alba'},
#  {'name': 'BikeMi',
#   'id': 'bikemi',
#   'company': ['ClearChannel'],
#   'location': 'Milano'},
#  {'name': 'Biella',
#   'id': 'biella',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Biella'},
#  {'name': 'Chivasso',
#   'id': 'chivasso',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Chivasso'},
#  {'name': 'Bizi',
#   'id': 'bizi',
#   'company': ['ClearChannel'],
#   'location': 'Zaragoza'},
#  {'name': 'EcoBici',
#   'id': 'ecobici',
#   'company': ['ClearChannel'],
#   'location': 'Cd de México'},
#  {'name': 'Bici in Busto',
#   'id': 'bici-in-busto',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Busto Arsizio'},
#  {'name': 'Velo Antwerpen',
#   'id': 'velo-antwerpen',
#   'company': ['ClearChannel'],
#   'location': 'Antwerpen'},
#  {'name': 'Cuneo',
#   'id': 'cuneo',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Cuneo'},
#  {'name': 'Malmö by bike',
#   'id': 'malmobybike',
#   'company': ['ClearChannel'],
#   'location': 'Malmö'},
#  {'name': 'Bici las Condes',
#   'id': 'bicilascondes',
#   'company': ['ClearChannel'],
#   'location': 'Las Condes'},
#  {'name': 'BiciMAD',
#   'id': 'bicimad',
#   'company': 'Empresa Municipal de Transportes de Madrid, S.A.',
#   'location': 'Madrid'},
#  {'name': 'EasyBike',
#   'id': 'easybike-didymoteicho',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Didymoteicho'},
#  {'name': 'FRee Bike sharing',
#   'id': 'free-bike-sharing',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Frosinone'},
#  {'name': 'EasyBike',
#   'id': 'easybike-glyfada',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Glyfada'},
#  {'name': 'EasyBike',
#   'id': 'easybike-igoumenitsa',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Igoumenitsa'},
#  {'name': 'lecce',
#   'id': 'lecce',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Lecce'},
#  {'name': 'EasyBike',
#   'id': 'easybike-ioannina',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Ioannina'},
#  {'name': 'EasyBike',
#   'id': 'easybike-karditsa',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Karditsa'},
#  {'name': 'Manerba in Bici',
#   'id': 'manerba-in-bici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Manerba del Garda'},
#  {'name': 'EasyBike',
#   'id': 'easybike-kavala',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Kavala'},
#  {'name': 'EasyBike',
#   'id': 'easybike-kinouria',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Kinouria'},
#  {'name': 'EasyBike',
#   'id': 'easybike-komotini',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Komotini'},
#  {'name': 'EasyBike',
#   'id': 'easybike-patra',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Patra'},
#  {'name': 'Mar e Bici',
#   'id': 'mar-e-bici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Marciana Marina'},
#  {'name': 'EasyBike',
#   'id': 'easybike-rethymno',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Rethymno'},
#  {'name': 'EasyBike',
#   'id': 'easybike-samos',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Samos'},
#  {'name': 'Novara',
#   'id': 'novara',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Novara'},
#  {'name': 'EasyBike',
#   'id': 'easybike-nicosia',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Nicosia'},
#  {'name': 'EasyBike',
#   'id': 'easybike-mani',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Mani'},
#  {'name': 'EasyBike',
#   'id': 'easybike-irakleio',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Irakleio'},
#  {'name': 'ThessBike',
#   'id': 'thessbike',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Thessaloniki'},
#  {'name': 'AthensBikes',
#   'id': 'athens-bikes',
#   'company': ['Brainbox Technology', 'Smoove SAS'],
#   'location': 'Athens'},
#  {'name': 'GoodBike',
#   'id': 'goodbike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Padova'},
#  {'name': 'CicloSampa',
#   'id': 'ciclosampa',
#   'company': ['PegBike'],
#   'location': 'São Paulo'},
#  {'name': 'Bicicoruña',
#   'id': 'bicicorunha',
#   'company': None,
#   'location': 'A Coruña'},
#  {'name': 'BiciFerrolTerra',
#   'id': 'bici-ferrol-terra',
#   'company': ['Tuimil S.A.'],
#   'location': 'Ferrol - Narón'},
#  {'name': 'Curtin Bike Share',
#   'id': 'curtin-bike-share',
#   'company': ['Social Bicycles Inc.'],
#   'location': 'Curtin University, Perth, WA'},
#  {'name': 'Monash BikeShare',
#   'id': 'monash-bikeshare',
#   'company': ['Social Bicycles Inc.'],
#   'location': 'Melbourne, AU'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'mimuovofe',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Ferrara'},
#  {'name': 'Bixi',
#   'id': 'bixi-montreal',
#   'company': ['Motivate International, Inc.',
#    'PBSC Urban Solutions',
#    'BIXI Montréal'],
#   'location': 'Montréal, QC'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'parma',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Parma'},
#  {'name': 'Bike Share Toronto',
#   'id': 'bixi-toronto',
#   'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'],
#   'location': 'Toronto, ON'},
#  {'name': 'SoBi',
#   'id': 'sobi-hamilton',
#   'company': ['Social Bicycles Inc.'],
#   'location': 'Hamilton, ON'},
#  {'name': 'ArborBike',
#   'id': 'arborbike',
#   'company': ['Clean Energy Coalition', 'BCycle, LLC'],
#   'location': 'Ann Arbor, MI'},
#  {'name': 'Pavia in bici',
#   'id': 'pavia-in-bici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Pavia'},
#  {'name': 'Bici Perugia',
#   'id': 'bici-perugia',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Perugia'},
#  {'name': 'Austin B-cycle',
#   'id': 'austin',
#   'company': ['BCycle, LLC'],
#   'location': 'Austin, TX'},
#  {'name': 'Bike Chattanooga',
#   'id': 'bike-chattanooga',
#   'company': ['Motivate International, Inc', 'PBSC'],
#   'location': 'Chattanooga, TN'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'piacenza',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Piacenza'},
#  {'name': 'Pinerolo',
#   'id': 'pinerolo',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Pinerolo'},
#  {'name': 'BIKETOWN',
#   'id': 'biketown',
#   'company': ['Portland Bureau of Transportation (PBOT)',
#    'Motivate International, Inc',
#    'Social Bicycles Inc.'],
#   'location': 'Portland, OR'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'reggio-emilia',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Reggio Emilia'},
#  {'name': 'BRiteBikes',
#   'id': 'britebikes',
#   'company': ['CycleHop, LLC', 'Social Bicycles Inc.'],
#   'location': 'San Ramon, CA'},
#  {'name': 'Boise GreenBike',
#   'id': 'boise-greenbike',
#   'company': ['ValleyRide', 'Social Bicycles Inc.'],
#   'location': 'Boise, ID'},
#  {'name': 'Boulder B-cycle',
#   'id': 'boulder',
#   'company': ['BCycle, LLC'],
#   'location': 'Boulder, CO'},
#  {'name': 'Breeze Bike Share',
#   'id': 'breeze-bike-share',
#   'company': ['CycleHop, LLC', 'Social Bicycles Inc.'],
#   'location': 'Santa Monica, CA'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'rimini',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Rimini'},
#  {'name': 'Broward B-cycle',
#   'id': 'broward',
#   'company': ['BCycle, LLC'],
#   'location': 'Fort Lauderdale, FL'},
#  {'name': 'Bublr Bikes',
#   'id': 'bublr-bikes',
#   'company': ['BCycle, LLC'],
#   'location': 'Milwaukee, WI'},
#  {'name': 'Reddy Bike Share',
#   'id': 'reddy-bike-share',
#   'company': ['Shared Mobility Inc.', 'Social Bicycles Inc.'],
#   'location': 'Buffalo, NY'},
#  {'name': 'Capital BikeShare',
#   'id': 'capital-bikeshare',
#   'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'],
#   'location': 'Washington, DC'},
#  {'name': 'Charlotte B-cycle',
#   'id': 'charlotte',
#   'company': ['BCycle, LLC'],
#   'location': 'Charlotte, NC'},
#  {'name': 'Saluzzo',
#   'id': 'saluzzo',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Saluzzo'},
#  {'name': 'Cincy Red Bike',
#   'id': 'cincy-red-bike',
#   'company': ['BCycle, LLC'],
#   'location': 'Cincinnati, OH'},
#  {'name': 'Savigliano',
#   'id': 'savigliano',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Savigliano'},
#  {'name': 'Citi Bike',
#   'id': 'citi-bike-nyc',
#   'company': ['NYC Bike Share, LLC',
#    'Motivate International, Inc.',
#    'PBSC Urban Solutions'],
#   'location': 'New York, NY'},
#  {'name': 'Coast Bike Share',
#   'id': 'coast-bike-share',
#   'company': ['CycleHop, LLC'],
#   'location': 'Tampa, FL'},
#  {'name': 'Terni',
#   'id': 'terni',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Terni'},
#  {'name': 'CoGo',
#   'id': 'cogo',
#   'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'],
#   'location': 'Columbus, OH'},
#  {'name': 'Denver B-cycle',
#   'id': 'denver',
#   'company': ['BCycle, LLC'],
#   'location': 'Denver, CO'},
#  {'name': 'Divvy',
#   'id': 'divvy',
#   'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'],
#   'location': 'Chicago, IL'},
#  {'name': 'Tirano in Bici',
#   'id': 'tirano-in-bici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Tirano'},
#  {'name': 'El Paso B-cycle',
#   'id': 'elpaso',
#   'company': ['BCycle, LLC'],
#   'location': 'El Paso, TX'},
#  {'name': 'Fort Worth Bike Sharing',
#   'id': 'fortworth',
#   'company': ['BCycle, LLC'],
#   'location': 'Fort Worth, TX'},
#  {'name': 'Udine',
#   'id': 'udine',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Udine'},
#  {'name': 'Great Rides Bike Share',
#   'id': 'greatrides',
#   'company': ['BCycle, LLC'],
#   'location': 'Fargo, ND'},
#  {'name': 'GREENbike',
#   'id': 'greenbikeslc',
#   'company': ['BCycle, LLC'],
#   'location': 'Salt Lake City'},
#  {'name': 'Grid Bike Share',
#   'id': 'grid-bike-share',
#   'company': ['CycleHop, LLC', 'Social Bicycles Inc.'],
#   'location': 'Phoenix, AZ'},
#  {'name': 'Heartland B-cycle',
#   'id': 'omaha',
#   'company': ['BCycle, LLC'],
#   'location': 'Omaha, NE'},
#  {'name': 'Houston B-cycle',
#   'id': 'houston',
#   'company': ['BCycle, LLC'],
#   'location': 'Houston, TX'},
#  {'name': 'Blue Bikes',
#   'id': 'blue-bikes',
#   'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'],
#   'location': 'Boston, MA'},
#  {'name': 'Ustica',
#   'id': 'ustica',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Ustica'},
#  {'name': 'Indego',
#   'id': 'indego',
#   'company': ['City of Philadelphia',
#    'Bicycle Transit Systems',
#    'BCycle, LLC'],
#   'location': 'Philadelphia, PA'},
#  {'name': 'Indiana Pacers Bikeshare',
#   'id': 'indiana-pacers-bikeshare',
#   'company': ['BCycle, LLC'],
#   'location': 'Indianapolis, IN'},
#  {'name': 'Juice',
#   'id': 'juice-bike-share',
#   'company': ['CycleHop, LLC', 'Social Bicycles Inc.'],
#   'location': 'Orlando, FL'},
#  {'name': 'BICI&CO',
#   'id': 'bici-co',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Como'},
#  {'name': 'B-cycle',
#   'id': 'kansascity',
#   'company': ['BCycle, LLC'],
#   'location': 'Kansas City, MO'},
#  {'name': 'Link',
#   'id': 'linkdayton',
#   'company': ['BCycle, LLC'],
#   'location': 'Dayton, OH'},
#  {'name': 'B-cycle',
#   'id': 'madison',
#   'company': ['BCycle, LLC'],
#   'location': 'Madison, WI'},
#  {'name': 'Metro Bike Share',
#   'id': 'metro-bike-share',
#   'company': ['Los Angeles County Metropolitan Transportation Authority (Metro)',
#    'Bicycle Transit Systems',
#    'BCycle, LLC'],
#   'location': 'Los Angeles, CA'},
#  {'name': 'Mountain Rides Bike Share',
#   'id': 'mountain-rides-bike-share',
#   'company': ['Mountain Rides', 'Social Bicycles Inc.'],
#   'location': 'Ketchum / Sun Valley, ID'},
#  {'name': 'Nice Ride',
#   'id': 'nice-ride',
#   'company': ['Nice Ride Minnesota', 'Lyft'],
#   'location': 'Minneapolis, MN'},
#  {'name': 'Speziainbici',
#   'id': 'speziainbici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'La Spezia'},
#  {'name': 'SWell Cycle',
#   'id': 'sanantonio',
#   'company': ['BCycle, LLC'],
#   'location': 'San Antonio, TX'},
#  {'name': 'Share-a-Bull Bikes',
#   'id': 'share-a-bull-bikes',
#   'company': ['Social Bicycles Inc.'],
#   'location': 'University of South Florida, FL'},
#  {'name': 'Venezia',
#   'id': 'venezia',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Venezia'},
#  {'name': 'SoBi',
#   'id': 'sobi-long-beach',
#   'company': ['Social Bicycles Inc.'],
#   'location': 'Long Beach, NY'},
#  {'name': 'Spartanburg BCycle',
#   'id': 'spartanburg',
#   'company': ['BCycle, LLC'],
#   'location': 'Spartanburg, SC'},
#  {'name': 'Topeka Metro Bikes',
#   'id': 'topeka-metro-bikes',
#   'company': ['Topeka Metropolitan Transit Authority', 'Social Bicycles Inc.'],
#   'location': 'Topeka, KS'},
#  {'name': '[TO]BIKE',
#   'id': 'to-bike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Torino'},
#  {'name': 'UBike',
#   'id': 'ubike',
#   'company': ['Social Bicycles Inc.'],
#   'location': 'University of Virginia, VA'},
#  {'name': 'Relay Bike Share',
#   'id': 'relay-atlanta',
#   'company': ['CycleHop, LLC', 'Social Bicycles Inc'],
#   'location': 'Atlanta, GA'},
#  {'name': 'BikeRecife',
#   'id': 'bikerecife',
#   'company': ['Tembici', 'PBSC Urban Solutions'],
#   'location': 'Recife'},
#  {'name': 'BikeSampa',
#   'id': 'bikesampa',
#   'company': ['Tembici', 'PBSC Urban Solutions'],
#   'location': 'São Paulo'},
#  {'name': 'BikeRio',
#   'id': 'bikerio',
#   'company': ['Tembici', 'PBSC Urban Solutions'],
#   'location': 'Rio de Janeiro'},
#  {'name': 'BikeSalvador',
#   'id': 'bikesalvador',
#   'company': ['Tembici', 'PBSC Urban Solutions'],
#   'location': 'Salvador'},
#  {'name': 'BikePOA',
#   'id': 'bikepoa',
#   'company': ['Tembici', 'PBSC Urban Solutions'],
#   'location': 'Porto Alegre'},
#  {'name': 'MIBICI',
#   'id': 'mibici-guadalajara',
#   'company': ['BKT bici publica S.A. de C.V.', 'PBSC Urban Solutions'],
#   'location': 'Guadalajara'},
#  {'name': 'Just Eat Cycles',
#   'id': 'edinburgh-cycle-hire',
#   'company': ['Your Bike', 'Urban Sharing'],
#   'location': 'Edinburgh'},
#  {'name': 'Melbourne Bike Share',
#   'id': 'melbourne-bike-share',
#   'company': ['PBSC', 'Alta Bicycle Share, Inc'],
#   'location': 'Melbourne'},
#  {'name': 'Libélo',
#   'id': 'libelo',
#   'company': ['PBSC Urban Solutions'],
#   'location': 'Valence'},
#  {'name': 'BikeSantiago',
#   'id': 'bikesantiago',
#   'company': ['Tembici', 'PBSC Urban Solutions'],
#   'location': 'Santiago'},
#  {'name': 'Bysykkel',
#   'id': 'oslo-bysykkel',
#   'company': None,
#   'location': 'Oslo'},
#  {'name': 'Bysykkel',
#   'id': 'bergen-bysykkel',
#   'company': None,
#   'location': 'Bergen'},
#  {'name': 'Bysykkel',
#   'id': 'trondheim-bysykkel',
#   'company': None,
#   'location': 'Trondheim'},
#  {'name': 'LE vélo Star',
#   'id': 'le-velo-star',
#   'company': ['Keolis', 'Rennes Metropole'],
#   'location': 'Rennes'},
#  {'name': 'V³',
#   'id': 'v3-bordeaux',
#   'company': ['Keolis Bordeaux Métropole'],
#   'location': 'Bordeaux'},
#  {'name': "V'Lille",
#   'id': 'vlille',
#   'company': ['Keolis'],
#   'location': 'Lille'},
#  {'name': 'IDECycle',
#   'id': 'idecycle',
#   'company': ['Keolis', 'STAP'],
#   'location': 'Pau'},
#  {'name': 'Bicialtea',
#   'id': 'bicialtea',
#   'company': ['Labici Bicicletas Públicas SL'],
#   'location': 'Altea'},
#  {'name': 'Bicidorm',
#   'id': 'bicidorm',
#   'company': ['Labici Bicicletas Públicas SL'],
#   'location': 'Benidorm'},
#  {'name': 'SaforBici',
#   'id': 'saforbici',
#   'company': ['Labici Bicicletas Públicas SL'],
#   'location': 'Gandía'},
#  {'name': 'Ciclopi',
#   'id': 'ciclopi',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Pisa'},
#  {'name': 'Gbici',
#   'id': 'gbici',
#   'company': ['Labici Bicicletas Públicas SL'],
#   'location': 'Getafe'},
#  {'name': 'MuyBici',
#   'id': 'muybici',
#   'company': ['Labici Bicicletas Públicas SL'],
#   'location': 'Murcia'},
#  {'name': 'PonfeMobi',
#   'id': 'ponfemobi',
#   'company': ['Labici Bicicletas Públicas SL'],
#   'location': 'Ponferrada'},
#  {'name': 'VaiBike',
#   'id': 'vaibike',
#   'company': ['Labici Bicicletas Públicas SL'],
#   'location': 'Vilagarcía de Arousa'},
#  {'name': 'Cagliari',
#   'id': 'cagliari',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Cagliari'},
#  {'name': 'Ecobici',
#   'id': 'ecobici-buenos-aires',
#   'company': ['Buenos Aires Ciudad'],
#   'location': 'Buenos Aires'},
#  {'name': 'Gira', 'id': 'gira', 'company': ['EMEL'], 'location': 'Lisbon'},
#  {'name': 'Gimme Bike',
#   'id': 'gimme-bike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Varese'},
#  {'name': "cy'clic",
#   'id': 'cyclic',
#   'company': ['JCDecaux'],
#   'location': 'Rouen'},
#  {'name': 'Vélô',
#   'id': 'velo',
#   'company': ['JCDecaux'],
#   'location': 'Toulouse'},
#  {'name': 'Veloh',
#   'id': 'veloh',
#   'company': ['JCDecaux'],
#   'location': 'Luxembourg'},
#  {'name': 'Valenbisi',
#   'id': 'valenbisi',
#   'company': ['JCDecaux'],
#   'location': 'Valencia'},
#  {'name': 'Sellero',
#   'id': 'sellero',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Sellero'},
#  {'name': 'Styr & Ställ',
#   'id': 'goeteborg',
#   'company': ['JCDecaux'],
#   'location': 'Göteborg'},
#  {'name': 'Lundahoj',
#   'id': 'lundahoj',
#   'company': ['JCDecaux'],
#   'location': 'Lund'},
#  {'name': 'Ugento',
#   'id': 'ugento',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Ugento'},
#  {'name': 'Tusbic',
#   'id': 'tusbic',
#   'company': ['JCDecaux'],
#   'location': 'Santander'},
#  {'name': 'Velam',
#   'id': 'velam',
#   'company': ['JCDecaux'],
#   'location': 'Amiens'},
#  {'name': 'Bysykkel',
#   'id': 'bysykkel-lillestrom',
#   'company': ['JCDecaux'],
#   'location': 'Lillestrøm'},
#  {'name': 'VéloCité',
#   'id': 'velocite-mulhouse',
#   'company': ['JCDecaux'],
#   'location': 'Mulhouse'},
#  {'name': 'Prata Camportaccio',
#   'id': 'prata-camportaccio',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Prata Camportaccio'},
#  {'name': "Vélo'V",
#   'id': 'velov',
#   'company': ['JCDecaux'],
#   'location': 'Lyon'},
#  {'name': 'Bicikelj',
#   'id': 'bicikelj',
#   'company': ['JCDecaux'],
#   'location': 'Ljubljana'},
#  {'name': 'Civitavecchia',
#   'id': 'civitavecchia',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Civitavecchia'},
#  {'name': 'Sevici',
#   'id': 'sevici',
#   'company': ['JCDecaux'],
#   'location': 'Sevilla'},
#  {'name': 'LonganoinBici',
#   'id': 'longanoinbici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Barcellona Pozzo di Gotto'},
#  {'name': 'Li bia velo',
#   'id': 'li-bia-velo',
#   'company': ['JCDecaux'],
#   'location': 'Namur'},
#  {'name': "vélOstan'lib",
#   'id': 'velostanlib',
#   'company': ['JCDecaux'],
#   'location': 'Nancy'},
#  {'name': 'Cristolib',
#   'id': 'cristolib',
#   'company': ['JCDecaux'],
#   'location': 'Créteil'},
#  {'name': 'villo',
#   'id': 'villo',
#   'company': ['JCDecaux'],
#   'location': 'Bruxelles'},
#  {'name': "Cassano d'Adda",
#   'id': 'cassano-d-adda',
#   'company': ['Comunicare S.r.l.'],
#   'location': "Cassano d'Adda"},
#  {'name': 'Velo2',
#   'id': 'velo2',
#   'company': ['JCDecaux'],
#   'location': 'Cergy'},
#  {'name': 'Cyclocity',
#   'id': 'vilnius-cyclocity',
#   'company': ['JCDecaux'],
#   'location': 'Vilnius'},
#  {'name': 'cyclocity',
#   'id': 'toyama-cyclocity',
#   'company': ['JCDecaux'],
#   'location': '富山市'},
#  {'name': "Veli'k",
#   'id': 'velik',
#   'company': ['JCDecaux'],
#   'location': 'Казань'},
#  {'name': 'Bianzone in Bici',
#   'id': 'bianzone-in-bici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Bianzone'},
#  {'name': 'Le vélo',
#   'id': 'le-velo',
#   'company': ['JCDecaux'],
#   'location': 'Marseille'},
#  {'name': 'Bicloo',
#   'id': 'bicloo',
#   'company': ['JCDecaux'],
#   'location': 'Nantes'},
#  {'name': 'VéloCité',
#   'id': 'velocite-besancon',
#   'company': ['JCDecaux'],
#   'location': 'Besançon'},
#  {'name': 'Rietinbici',
#   'id': 'rietinbici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Rieti'},
#  {'name': 'dublinbikes',
#   'id': 'dublinbikes',
#   'company': ['JCDecaux'],
#   'location': 'Dublin'},
#  {'name': 'CityCycle',
#   'id': 'citycycle',
#   'company': ['JCDecaux'],
#   'location': 'Brisbane'},
#  {'name': 'Bicipalma',
#   'id': 'bicipalma',
#   'company': None,
#   'location': 'Palma'},
#  {'name': 'ADCB Bikeshare',
#   'id': 'adcb-bikeshare',
#   'company': ['Cyacle Bicycle Rental LLC'],
#   'location': 'Abu Dhabi'},
#  {'name': 'Castellucchio',
#   'id': 'castellucchio',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Castellucchio'},
#  {'name': 'Vélo Bleu',
#   'id': 'velobleu',
#   'company': ['Veolia'],
#   'location': 'Nice'},
#  {'name': 'NotoinBici',
#   'id': 'notoinbici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Noto'},
#  {'name': 'Enna',
#   'id': 'enna',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Enna'},
#  {'name': 'Pordenone',
#   'id': 'pordenone',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Pordenone'},
#  {'name': "Vél'in",
#   'id': 'vel-in',
#   'company': ['Veolia'],
#   'location': 'Calais'},
#  {'name': 'Carbonia',
#   'id': 'carbonia',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Carbonia'},
#  {'name': 'Cluj Bike',
#   'id': 'clujbike',
#   'company': ['Municipiul Cluj-Napoca'],
#   'location': 'Cluj-Napoca'},
#  {'name': 'MoBike',
#   'id': 'mobike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Genova'},
#  {'name': 'Integrabike',
#   'id': 'integrabike',
#   'company': ['Prefeiture de Sorocaba', 'Urbes'],
#   'location': 'Sorocaba'},
#  {'name': 'Scegli in Bici',
#   'id': 'scegli-in-bici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Cremona'},
#  {'name': 'RiviBike',
#   'id': 'rivibike',
#   'company': ['Associação dos Amigos da Riviera de São Lourenço', 'Sobloco'],
#   'location': 'São Lourenço'},
#  {'name': 'e.motion',
#   'id': 'e-motion-trento',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Trento'},
#  {'name': 'DukeBike',
#   'id': 'dukebike',
#   'company': ['Duke Energy Brasil', 'Governo de Ipaussu'],
#   'location': 'Ipaússu'},
#  {'name': 'Bicing',
#   'id': 'bicing',
#   'company': ['Barcelona de Serveis Municipals, S.A. (BSM)', 'CESPA', 'PBSC'],
#   'location': 'Barcelona'},
#  {'name': 'Baksi',
#   'id': 'baksi-antalya',
#   'company': ['Baksi Bike Sharing System'],
#   'location': 'Antalya'},
#  {'name': 'Baksi',
#   'id': 'baksi-bisim',
#   'company': ['Baksi Bike Sharing System'],
#   'location': 'Izmir'},
#  {'name': 'e.motion',
#   'id': 'e-motion-rovereto',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Rovereto'},
#  {'name': 'Isbike',
#   'id': 'baksi-istanbul',
#   'company': ['Baksi Bike Sharing System'],
#   'location': 'Istanbul'},
#  {'name': 'Baksi',
#   'id': 'baksi-kobis',
#   'company': ['Baksi Bike Sharing System'],
#   'location': 'Kocaeli'},
#  {'name': 'City bikes',
#   'id': 'citybikes-helsinki',
#   'company': ['Helsinki City Transport',
#    'Helsinki Regional Transport',
#    'CityBikeFinland',
#    'Smoove SAS',
#    'Moventia',
#    'Alepa'],
#   'location': 'Helsinki'},
#  {'name': 'Monopoli BIKE',
#   'id': 'monopoli-bike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Monopoli'},
#  {'name': 'Föli-fillari',
#   'id': 'foli',
#   'company': ['Turku Region Traffic Föli', 'Nextbike Polska'],
#   'location': 'Turku'},
#  {'name': 'bicimia',
#   'id': 'bicimia',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Brescia'},
#  {'name': 'Tel-O-Fun',
#   'id': 'telofun',
#   'company': ['FSM Ground Services Ltd.'],
#   'location': "Tel Aviv-Yaffo, Giv'atayim, Ramat-Gan"},
#  {'name': 'Andria in Bici',
#   'id': 'andria',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Andria'},
#  {'name': 'WhiteBikes',
#   'id': 'whitebikes',
#   'company': ['Open Source Bike Share'],
#   'location': 'Bratislava'},
#  {'name': 'Slovnaft BAjk',
#   'id': 'slovnaft-bajk',
#   'company': ['Dopravný podnik Bratislava',
#    'Bratislavská integrovaná doprava, a.s.',
#    'Hlavné mesto SR Bratislava'],
#   'location': 'Bratislava'},
#  {'name': 'Cykl',
#   'id': 'cykl',
#   'company': ['Open Source Bike Share'],
#   'location': 'Wageningen'},
#  {'name': 'Bicykle za dobré skutky',
#   'id': 'bicyklezadobreskutky',
#   'company': ['Open Source Bike Share'],
#   'location': 'Prešov'},
#  {'name': 'Wavelo',
#   'id': 'socialbicycles-wavelo',
#   'company': ['Social Bicycles Inc.'],
#   'location': 'Kraków'},
#  {'name': 'BicinQuartucciu',
#   'id': 'bicinquartucciu',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Quartucciu'},
#  {'name': 'MVGmeinrad',
#   'id': 'mvgmeinrad',
#   'company': ['Mainzer Verkehrsgesellschaft mbH (MVG)'],
#   'location': 'Mainz'},
#  {'name': 'EnCicla',
#   'id': 'encicla',
#   'company': ['Sistema de Bicicletas Públicas del Valle de Aburrá'],
#   'location': 'Medellin'},
#  {'name': 'Olbia Bike',
#   'id': 'olbia-bike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Olbia'},
#  {'name': 'Mobi',
#   'id': 'mobibikes',
#   'company': ['Vanncouver Bike Share Inc',
#    'CycleHop LLC',
#    'City of Vancouver',
#    'Smoove SAS'],
#   'location': 'Vancouver'},
#  {'name': 'Savona',
#   'id': 'savona',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Savona'},
#  {'name': 'C.vélo',
#   'id': 'c-velo',
#   'company': ['CityBike France', 'PBSC Urban Solutions'],
#   'location': 'Clermont-Ferrand'},
#  {'name': 'VéliVert',
#   'id': 'velivert',
#   'company': ['Smoove'],
#   'location': 'Saint-Étienne'},
#  {'name': 'BrindisiByBike',
#   'id': 'brindisi',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Brindisi'},
#  {'name': 'Vélopop',
#   'id': 'velopop',
#   'company': ['Smoove'],
#   'location': 'Avignon'},
#  {'name': 'Batumvelo',
#   'id': 'batumvelo',
#   'company': ['Smoove'],
#   'location': 'Batumi'},
#  {'name': 'Tradate',
#   'id': 'tradate',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Tradate'},
#  {'name': 'BikeBH',
#   'id': 'bikebh',
#   'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#   'location': 'Belo Horizonte'},
#  {'name': 'BikePetrolina',
#   'id': 'bikepetrolina',
#   'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#   'location': 'Petrolina'},
#  {'name': 'JesinBici',
#   'id': 'jesinbici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Jesi'},
#  {'name': 'nbici',
#   'id': 'nbici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Pamplona'},
#  {'name': 'BikeBrasilia',
#   'id': 'bikebrasilia',
#   'company': ['Tembici'],
#   'location': 'Brasília'},
#  {'name': 'GynDebike',
#   'id': 'debikegoiania',
#   'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#   'location': 'Goiânia'},
#  {'name': 'Treviso',
#   'id': 'treviso',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Treviso'},
#  {'name': 'Bicicletar',
#   'id': 'bicicletar',
#   'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#   'location': 'Fortaleza'},
#  {'name': 'CajuBike',
#   'id': 'cajubike',
#   'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#   'location': 'Aracajú'},
#  {'name': 'Bike Belém',
#   'id': 'bikebelem',
#   'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#   'location': 'Belém'},
#  {'name': 'Sondrio',
#   'id': 'sondrio',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Sondrio'},
#  {'name': 'BikeSantos',
#   'id': 'bikesantos',
#   'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#   'location': 'Santos'},
#  {'name': 'Vercelli',
#   'id': 'vercelli',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Vercelli'},
#  {'name': 'Portofino Park and Bike',
#   'id': 'portofino-park-and-bike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Santa Margherita Ligure - Portofino - Camogli'},
#  {'name': 'Mi bici tu bici',
#   'id': 'mibicitubici',
#   'company': ['Mobilicidade Tecnologia LTD', 'Municipalidad de Rosario'],
#   'location': 'Rosario'},
#  {'name': 'Citi Bike Miami',
#   'id': 'decobike-miami-beach',
#   'company': ['DecoBike LLC'],
#   'location': 'Miami Beach, FL'},
#  {'name': 'Decobike San Diego',
#   'id': 'decobike-san-diego',
#   'company': ['DecoBike LLC'],
#   'location': 'San Diego, CA'},
#  {'name': 'Meglio in Bici',
#   'id': 'meglio-in-bici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Cernusco sul Naviglio - Pioltello - Carugate'},
#  {'name': 'Des Moines B-cycle',
#   'id': 'desmoines',
#   'company': ['BCycle, LLC'],
#   'location': 'Des Moines, IA'},
#  {'name': "Comunità Montana Valli dell'Ossola",
#   'id': 'ossola',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Santa Maria Maggiore - Malesco - Villette'},
#  {'name': 'Greenville B-cycle',
#   'id': 'greenville',
#   'company': ['BCycle, LLC'],
#   'location': 'Greenville, SC'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-mezzolombardo',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Mezzolombardo'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-lausanne-campus-morges',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Lausanne - Morges - Campus'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-scafati',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Scafati'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-livorno',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Livorno'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-valais-central',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Sion'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'bicincitta-forli',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Forlì'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-rivarolo-canavese',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Rivarolo Canavese'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-monserrato',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Monserrato'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-mezzocorona',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Mezzocorona'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'bicincitta-san-lazzaro-di-savena',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'San Lazzaro di Savena'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-san-teodoro',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'San Teodoro'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-parco-molentargius-saline',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Parco Naturale Molentargius - Saline'},
#  {'name': 'Parkinbici',
#   'id': 'parkinbici',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Parco Nazionale del Gargano'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-gallipoli',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Gallipoli'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-castel-guelfo-the-style-outlets',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Castel Guelfo di Bologna'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-san-michele-alladige',
#   'company': ['Comunicare S.r.l.'],
#   'location': "San Michele All'adige"},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-agglo-fribourg',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Fribourg'},
#  {'name': 'Mi Muovo in bici',
#   'id': 'bicincitta-modena',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Modena'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-brancaleone',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Brancaleone'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-bulle',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Bulle'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-riviera',
#   'company': ['Comunicare S.r.l.'],
#   'location': "Distretto della Riviera-Pays-d'Enhaut"},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'bicincitta-scandiano',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Scandiano'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-elmas',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Elmas'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-tivat',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'TV'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-acquaviva-delle-fonti',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Acquaviva delle fonti'},
#  {'name': 'We Love bike',
#   'id': 'we-love-bike',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Lodi'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-acquarica-del-capo',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Acquarica del Capo'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-vicolungo-the-style-outlets',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Vicolungo'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-porto-torres',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Porto Torres'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-cisterna-di-latina',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Cisterna di Latina'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-casaletto-spartano',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Casaletto Spartano'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-selargius',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Selargius'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-yverdon-les-bains',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Yverdon-les-Bains'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-monza',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Monza'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-la-cote',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Nyon'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-morigerati',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Morigerati'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-san-donato-milanese',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'San Donato Milanese'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-chablais',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Monthey - Aigle'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-ente-parco-del-circeo',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Parco Nazionale del Circeo'},
#  {'name': 'Mi Muovo in bici',
#   'id': 'bicincitta-cesena',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Cesena'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-lugano-paradiso',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Paradiso'},
#  {'name': 'Bicincittà',
#   'id': 'lecco',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Lecco'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-alghero',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Alghero'},
#  {'name': 'Mi Muovo in Bici',
#   'id': 'bicincitta-san-giovanni-in-persiceto',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'San Giovanni in Persiceto'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-ente-parco-san-rossore',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Parco naturale Migliarino San Rossore Massaciuccoli'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-treviglio',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Treviglio'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-lavis',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Lavis'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-les-lacs-romont',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Murten'},
#  {'name': 'Bicincittà',
#   'id': 'bicincitta-ente-parco-di-montemarcello-magra',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Ente Parco Montemarcello Magra'},
#  {'name': 'BiciSchio',
#   'id': 'bicischio',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Schio'},
#  {'name': 'Mi Muovo in bici',
#   'id': 'bicincitta-imola',
#   'company': ['Comunicare S.r.l.'],
#   'location': 'Imola'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-leipzig',
#   'company': ['Nextbike GmbH'],
#   'location': 'Leipzig'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-wiesbaden',
#   'company': ['Nextbike GmbH'],
#   'location': 'Wiesbaden'},
#  {'name': 'VISA',
#   'id': 'visa-frankfurt',
#   'company': ['Nextbike GmbH'],
#   'location': 'Frankfurt'},
#  {'name': 'KVB Rad',
#   'id': 'kvb-rad-koln',
#   'company': ['Nextbike GmbH'],
#   'location': 'Köln'},
#  {'name': 'Fächerrad',
#   'id': 'facherrad-karlsruhe',
#   'company': ['Nextbike GmbH'],
#   'location': 'Karlsruhe'},
#  {'name': 'Burgenland',
#   'id': 'burgenland-neusiedler-see',
#   'company': ['Nextbike GmbH'],
#   'location': 'Neusiedler See'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-dusseldorf',
#   'company': ['Nextbike GmbH'],
#   'location': 'Düsseldorf'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-stpolten',
#   'company': ['Nextbike GmbH'],
#   'location': 'St.Pölten'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-modling',
#   'company': ['Nextbike GmbH'],
#   'location': 'Mödling'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-sursee',
#   'company': ['Nextbike GmbH'],
#   'location': 'Sursee'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-luzern',
#   'company': ['Nextbike GmbH'],
#   'location': 'Luzern'},
#  {'name': 'SiXT',
#   'id': 'sixt-riga',
#   'company': ['Nextbike GmbH'],
#   'location': 'Rīga'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-dortmund',
#   'company': ['Nextbike GmbH'],
#   'location': 'Dortmund'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-bochum',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bochum'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-bottrop',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bottrop'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-duisburg',
#   'company': ['Nextbike GmbH'],
#   'location': 'Duisburg'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-essen',
#   'company': ['Nextbike GmbH'],
#   'location': 'Essen'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-gelsenkirchen',
#   'company': ['Nextbike GmbH'],
#   'location': 'Gelsenkirchen'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-hamm',
#   'company': ['Nextbike GmbH'],
#   'location': 'Hamm'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-herne',
#   'company': ['Nextbike GmbH'],
#   'location': 'Herne'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-mulheim-adr',
#   'company': ['Nextbike GmbH'],
#   'location': 'Mülheim a.d.R.'},
#  {'name': 'metropolradruhr',
#   'id': 'metropolradruhr-oberhausen',
#   'company': ['Nextbike GmbH'],
#   'location': 'Oberhausen'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-wachau',
#   'company': ['Nextbike GmbH'],
#   'location': 'Wachau'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-tulln',
#   'company': ['Nextbike GmbH'],
#   'location': 'Tulln'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-thermenregion',
#   'company': ['Nextbike GmbH'],
#   'location': 'Thermenregion'},
#  {'name': 'WRM',
#   'id': 'wrm-wroclaw',
#   'company': ['Nextbike GmbH'],
#   'location': 'Wrocław'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-offenburg',
#   'company': ['Nextbike GmbH'],
#   'location': 'Offenburg'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-wrneustadt',
#   'company': ['Nextbike GmbH'],
#   'location': 'Wr.Neustadt'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-potsdam',
#   'company': ['Nextbike GmbH'],
#   'location': 'Potsdam'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-gutersloh',
#   'company': ['Nextbike GmbH'],
#   'location': 'Gütersloh'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-10vorwien',
#   'company': ['Nextbike GmbH'],
#   'location': '10vorWien'},
#  {'name': 'UsedomRad',
#   'id': 'usedomrad-usedom',
#   'company': ['Nextbike GmbH'],
#   'location': 'Usedom'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-norderstedt',
#   'company': ['Nextbike GmbH'],
#   'location': 'Norderstedt'},
#  {'name': 'SWA Rad',
#   'id': 'swa-rad-augsburg',
#   'company': ['Nextbike GmbH'],
#   'location': 'Augsburg'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-limassol',
#   'company': ['Nextbike GmbH'],
#   'location': 'Limassol'},
#  {'name': 'PRM',
#   'id': 'prm-poznan',
#   'company': ['Nextbike GmbH'],
#   'location': 'Poznań'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-christchurch',
#   'company': ['Nextbike GmbH'],
#   'location': 'Christchurch'},
#  {'name': 'VRN',
#   'id': 'vrn-heidelberg',
#   'company': ['Nextbike GmbH'],
#   'location': 'Heidelberg'},
#  {'name': 'VRN',
#   'id': 'vrn-mannheim',
#   'company': ['Nextbike GmbH'],
#   'location': 'Mannheim'},
#  {'name': 'Stadtrad',
#   'id': 'stadtrad-innsbruck',
#   'company': ['Nextbike GmbH'],
#   'location': 'Innsbruck'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-nicosia',
#   'company': ['Nextbike GmbH'],
#   'location': 'Nicosia'},
#  {'name': 'VETURILO',
#   'id': 'veturilo-warszawa',
#   'company': ['Nextbike GmbH'],
#   'location': 'Warszawa'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-hollabrunn',
#   'company': ['Nextbike GmbH'],
#   'location': 'Hollabrunn'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-wienerwald',
#   'company': ['Nextbike GmbH'],
#   'location': 'WienerWald'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-zagreb',
#   'company': ['Nextbike GmbH'],
#   'location': 'Zagreb'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-glasgow',
#   'company': ['Nextbike GmbH'],
#   'location': 'Glasgow'},
#  {'name': 'BelfastBikes',
#   'id': 'belfastbikes-belfast',
#   'company': ['Nextbike GmbH'],
#   'location': 'Belfast'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-stirling',
#   'company': ['Nextbike GmbH'],
#   'location': 'Stirling'},
#  {'name': 'Grad Šibenik',
#   'id': 'grad-sibenik-sibenik',
#   'company': ['Nextbike GmbH'],
#   'location': 'Šibenik'},
#  {'name': 'LRM Lublin',
#   'id': 'lrm-lublin-lublin',
#   'company': ['Nextbike GmbH'],
#   'location': 'Lublin'},
#  {'name': 'Healthy Ride',
#   'id': 'healthy-ride-pittsburgh-pittsburgh',
#   'company': ['Nextbike GmbH'],
#   'location': 'Pittsburgh'},
#  {'name': 'GRM Grodzisk',
#   'id': 'grm-grodzisk-grodzisk-mazowiecki',
#   'company': ['Nextbike GmbH'],
#   'location': 'Grodzisk Mazowiecki'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-quickborn',
#   'company': ['Nextbike GmbH'],
#   'location': 'Quickborn'},
#  {'name': 'VRN',
#   'id': 'vrn-ludwigshafen',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ludwigshafen'},
#  {'name': 'VRN',
#   'id': 'vrn-speyer',
#   'company': ['Nextbike GmbH'],
#   'location': 'Speyer'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-lviv',
#   'company': ['Nextbike GmbH'],
#   'location': 'Lviv'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-wurzburg',
#   'company': ['Nextbike GmbH'],
#   'location': 'Würzburg'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-serfaus',
#   'company': ['Nextbike GmbH'],
#   'location': 'Serfaus'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-malta',
#   'company': ['Nextbike GmbH'],
#   'location': 'Malta'},
#  {'name': 'Grad Karlovac',
#   'id': 'grad-karlovac-karlovac',
#   'company': ['Nextbike GmbH'],
#   'location': 'Karlovac'},
#  {'name': 'Grad Slavonski Brod',
#   'id': 'grad-slavonski-brod-slavonski-brod',
#   'company': ['Nextbike GmbH'],
#   'location': 'Slavonski Brod'},
#  {'name': 'Santander Cycles MK',
#   'id': 'santander-cycles-mk-milton-keynes',
#   'company': ['Nextbike GmbH'],
#   'location': 'Milton Keynes'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-hergiswil',
#   'company': ['Nextbike GmbH'],
#   'location': 'Hergiswil'},
#  {'name': 'Grad Makarska',
#   'id': 'grad-makarska-makarska',
#   'company': ['Nextbike GmbH'],
#   'location': 'Makarska'},
#  {'name': 'Općina Brinje',
#   'id': 'opcina-brinje-brinje',
#   'company': ['Nextbike GmbH'],
#   'location': 'Brinje'},
#  {'name': 'Grad Zadar',
#   'id': 'grad-zadar-zadar',
#   'company': ['Nextbike GmbH'],
#   'location': 'Zadar'},
#  {'name': 'VRN',
#   'id': 'vrn-bensheim',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bensheim'},
#  {'name': 'Grad Ivanić-Grad',
#   'id': 'grad-ivanic-grad-ivanic-grad',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ivanic Grad'},
#  {'name': 'Bike_S SRM',
#   'id': 'bike-s-srm-szczecin',
#   'company': ['Nextbike GmbH'],
#   'location': 'Szczecin'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-sarajevo',
#   'company': ['Nextbike GmbH'],
#   'location': 'Sarajevo'},
#  {'name': 'Co-bikes',
#   'id': 'co-bikes-exeter',
#   'company': ['Nextbike GmbH'],
#   'location': 'Exeter'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-auckland-waterfront',
#   'company': ['Nextbike GmbH'],
#   'location': 'Auckland Waterfront'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-berlin',
#   'company': ['Nextbike GmbH'],
#   'location': 'Berlin'},
#  {'name': 'Stacje Sponsorskie Nextbike Veturilo',
#   'id': 'veturilo-stacje-sponsorskie-nextbike-veturilo',
#   'company': ['Nextbike GmbH'],
#   'location': 'Warszawa'},
#  {'name': 'bike4all',
#   'id': 'bike4all-byblos',
#   'company': ['Nextbike GmbH'],
#   'location': 'Byblos'},
#  {'name': 'Chartered Bike',
#   'id': 'chartered-bike-bhopal-bhopal',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bhopal'},
#  {'name': 'WK-Bike',
#   'id': 'wk-bike-bremen-bremen',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bremen'},
#  {'name': 'VRN',
#   'id': 'vrn-worms',
#   'company': ['Nextbike GmbH'],
#   'location': 'Worms'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-stans',
#   'company': ['Nextbike GmbH'],
#   'location': 'Stans'},
#  {'name': 'Nextbike',
#   'id': 'nextbike-stansstad',
# ...
#   'location': 'Laon'},
#  {'name': 'Le Vélo Baulois',
#   'id': 'velo-baulois',
#   'company': ['Ecovelo'],
#   'location': 'La Baule-Escoublac'},
#  {'name': 'Le Marcel',
#   'id': 'le-marcel',
#   'company': ['Ecovelo'],
#   'location': 'Troyes'},
#  {'name': 'Tempo Vélo',
#   'id': 'tempo-velo',
#   'company': ['Ecovelo'],
#   'location': 'Agen'},
#  {'name': 'semo',
#   'id': 'semo',
#   'company': ['Ecovelo'],
#   'location': "Communauté d'agglomération Seine-Eure"},
#  {'name': 'Cyclovis',
#   'id': 'cyclovis',
#   'company': ['Ecovelo'],
#   'location': 'Soissons'},
#  {'name': 'Chantrerie VLS (Captain Bike)',
#   'id': 'chantrerie-captainbike',
#   'company': ['Ecovelo'],
#   'location': 'La Chantrerie, Nantes'},
#  {'name': 'Saclay VLS (Captain Bike)',
#   'id': 'saclay-captainbike',
#   'company': ['Ecovelo'],
#   'location': 'Paris-Saclay'},
#  {'name': "Vël'Ok",
#   'id': 'velok',
#   'company': ['CIGL ESCH'],
#   'location': 'Esch-sur-alzette'},
#  {'name': 'WienMobil Rad',
#   'id': 'wienmobil-rad',
#   'company': ['Nextbike GmbH'],
#   'location': 'Wien'},
#  {'name': 'Verona Bike',
#   'id': 'bikeverona',
#   'company': None,
#   'location': 'Verona'},
#  {'name': 'Sprottenflotte',
#   'id': 'sprottenflotte-kiel',
#   'company': ['Nextbike GmbH'],
#   'location': 'Kiel'},
#  {'name': 'Vélomagg',
#   'id': 'velomagg',
#   'company': ['TaM', 'Smoove'],
#   'location': 'Montpellier'},
#  {'name': 'RTC Bike Share',
#   'id': 'rtc-bike-share',
#   'company': ['Bcycle, LLC', 'RTC Southern Nevada, Inc'],
#   'location': 'Las Vegas, NV'},
#  {'name': 'Spokies BCycle',
#   'id': 'spokies',
#   'company': ['Bcycle, LLC', 'Embark, Inc'],
#   'location': 'Oklahoma, OK'},
#  {'name': 'Alsa nextbike León',
#   'id': 'alsa-nextbike-leon',
#   'company': ['Leonbici Nextbike Gmbh Y Autobuses Urbanos De Leon S.a. Ute'],
#   'location': 'León'},
#  {'name': 'Vélhop',
#   'id': 'velhop',
#   'company': ['Strasbourg Mobilités'],
#   'location': 'Strasbourg'},
#  {'name': 'Optymo', 'id': 'optymo', 'company': None, 'location': 'Belfort'},
#  {'name': 'BIKER Białystok Poland',
#   'id': 'biker-bialystok',
#   'company': ['Nextbike GmbH'],
#   'location': 'Białystok'},
#  {'name': 'nextbike Prostejov',
#   'id': 'nextbike-prostejov',
#   'company': ['Nextbike GmbH'],
#   'location': 'Prostejov'},
#  {'name': 'Katowice Bike Poland',
#   'id': 'bike-katowice',
#   'company': ['Nextbike GmbH'],
#   'location': 'Katowice'},
#  {'name': 'nextbike Romania',
#   'id': 'nextbike-focsani',
#   'company': ['Nextbike GmbH'],
#   'location': 'Focșani'},
#  {'name': 'Grad Vukovar (Croatia)',
#   'id': 'grad-vukovar',
#   'company': ['Nextbike GmbH'],
#   'location': 'Vukovar'},
#  {'name': 'System Rowerów Miejskich w Pszczynie Poland',
#   'id': 'system-rowerow-miejskich-w-pszczynie-pszczyna',
#   'company': ['Nextbike GmbH'],
#   'location': 'Pszczyna'},
#  {'name': 'Tyski Rower Miejski Poland',
#   'id': 'tyski-rower-miejski-tychy',
#   'company': ['Nextbike GmbH'],
#   'location': 'Tychy'},
#  {'name': 'Częstochowski Rower Miejski Poland',
#   'id': 'czestochowski-rower-miejski-czestochowa',
#   'company': ['Nextbike GmbH'],
#   'location': 'Częstochowa'},
#  {'name': 'Pruszkowski Rower Miejski Poland',
#   'id': 'pruszkowski-rower-miejski-pruszkow',
#   'company': ['Nextbike GmbH'],
#   'location': 'Pruszków'},
#  {'name': 'OK Bike Poland',
#   'id': 'ok-bike-kedzierzyn-kozle',
#   'company': ['Nextbike GmbH'],
#   'location': 'Kędzierzyn-Koźle'},
#  {'name': 'Grad Zaprešić (Croatia)',
#   'id': 'grad-zapresic',
#   'company': ['Nextbike GmbH'],
#   'location': 'Zaprešić'},
#  {'name': 'Porec bike share (Croatia)',
#   'id': 'porec-bike-share-porec',
#   'company': ['Nextbike GmbH'],
#   'location': 'Poreč'},
#  {'name': 'Kaliski Rower Miejski Poland',
#   'id': 'kaliski-rower-miejski-kalisz',
#   'company': ['Nextbike GmbH'],
#   'location': 'Kalisz'},
#  {'name': 'Rower Miejski w Ostrowie Wielkopolskim Poland',
#   'id': 'rower-miejski-w-ostrowie-wielkopolskim-ostrow-wielkopolski',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ostrów Wielkopolski'},
#  {'name': 'Santander Cycles - Brunel',
#   'id': 'santander-brunel',
#   'company': ['Nextbike GmbH'],
#   'location': 'Brunel University'},
#  {'name': 'Koszaliński Rower Miejski Poland',
#   'id': 'koszalinski-rower-miejski-koszalin',
#   'company': ['Nextbike GmbH'],
#   'location': 'Koszalin'},
#  {'name': 'Sosnowiecki Rower Miejski Poland',
#   'id': 'ki-rower-miejski-sosnowiec',
#   'company': ['Nextbike GmbH'],
#   'location': 'Sosnowiec'},
#  {'name': 'Pobiedziski Rower Gminny Poland',
#   'id': 'pobiedziski-rower-gminny-pobiedziska',
#   'company': ['Nextbike GmbH'],
#   'location': 'Pobiedziska'},
#  {'name': 'Siemianowicki Rower Miejski Poland',
#   'id': 'siemianowicki-rower-miejski-siemianowice-slaskie',
#   'company': ['Nextbike GmbH'],
#   'location': 'Siemianowice Śląskie'},
#  {'name': 'Piotrkowski Rower Miejski Poland',
#   'id': 'piotrkowski-rower-miejski-piotrkow-trybunalski',
#   'company': ['Nextbike GmbH'],
#   'location': 'Piotrków Trybunalski'},
#  {'name': 'Płocki Rower Miejski (PRM) Poland',
#   'id': 'i-rower-miejski-prm-plock',
#   'company': ['Nextbike GmbH'],
#   'location': 'Płock'},
#  {'name': 'Płocki Rower Miejski (PRM) Poland',
#   'id': 'plocki-rower-miejski-prm-orlen-plock',
#   'company': ['Nextbike GmbH'],
#   'location': 'Orlen Płock'},
#  {'name': 'Otwocki Rower Miejski Poland',
#   'id': 'i-rower-miejski-otwock',
#   'company': ['Nextbike GmbH'],
#   'location': 'Otwock'},
#  {'name': 'Ciechanowski Rower Miejski Poland',
#   'id': 'ciechanowski-rower-miejski-ciechanow',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ciechanów'},
#  {'name': 'Żyrardowski Rower Miejski Poland',
#   'id': 'zyrardowski-rower-miejski-zyrardow',
#   'company': ['Nextbike GmbH'],
#   'location': 'Żyrardów'},
#  {'name': 'SAP Walldorf',
#   'id': 'sap-walldorf',
#   'company': ['Nextbike GmbH'],
#   'location': 'Walldorf'},
#  {'name': 'Općina Dugopolje (Croatia)',
#   'id': 'opcina-dugopolje',
#   'company': ['Nextbike GmbH'],
#   'location': 'Dugopolje'},
#  {'name': 'Općina Pitomača (Croatia)',
#   'id': 'opcina-pitomaca',
#   'company': ['Nextbike GmbH'],
#   'location': 'Pitomača'},
#  {'name': 'Nomago Bikes - LJUBLJANA',
#   'id': 'nomago-ljubljana',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ljubljana'},
#  {'name': 'System Roweru Gminnego Poland',
#   'id': 'system-roweru-gminnego-pielgrzymka',
#   'company': ['Nextbike GmbH'],
#   'location': 'Pielgrzymka'},
#  {'name': 'RVK',
#   'id': 'rvk',
#   'company': ['Nextbike GmbH'],
#   'location': 'RVK e-Bike'},
#  {'name': 'Partnerzy Nextbike Polska',
#   'id': 'partnerzy-nextbike-polska-wolt',
#   'company': ['Nextbike GmbH'],
#   'location': 'Wolt'},
#  {'name': 'wupsiRad Leverkusen',
#   'id': 'wupsi',
#   'company': ['Nextbike GmbH'],
#   'location': 'Leverkusen'},
#  {'name': 'Lovesharing (Canary Islands)',
#   'id': 'lovesharing-canary-islands-gran-canaria',
#   'company': ['Nextbike GmbH'],
#   'location': 'Gran Canaria'},
#  {'name': 'Lovesharing (Canary Islands)',
#   'id': 'lovesharing-canary-islands-lanzarote',
#   'company': ['Nextbike GmbH'],
#   'location': 'Lanzarote'},
#  {'name': 'Lovesharing (Canary Islands)',
#   'id': 'lovesharing-canary-islands-fuerteventura',
#   'company': ['Nextbike GmbH'],
#   'location': 'Fuerteventura'},
#  {'name': 'VAG_Rad',
#   'id': 'vagrad',
#   'company': ['VAG Verkehrs-Aktiengesellschaft'],
#   'location': 'Nürnberg'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split',
#   'company': ['Nextbike GmbH'],
#   'location': 'Split'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-solin',
#   'company': ['Nextbike GmbH'],
#   'location': 'Solin'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-opcina-klis',
#   'company': ['Nextbike GmbH'],
#   'location': 'Općina Klis'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-opcina-hrvace',
#   'company': ['Nextbike GmbH'],
#   'location': 'Općina Hrvace'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-opcina-otok-dalmatinski',
#   'company': ['Nextbike GmbH'],
#   'location': 'Općina Otok Dalmatinski'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-sinj',
#   'company': ['Nextbike GmbH'],
#   'location': 'Sinj'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-hvar',
#   'company': ['Nextbike GmbH'],
#   'location': 'Hvar'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-podstrana',
#   'company': ['Nextbike GmbH'],
#   'location': 'Podstrana'},
#  {'name': 'Grad Split (Croatia)',
#   'id': 'grad-split-trogir',
#   'company': ['Nextbike GmbH'],
#   'location': 'Trogir'},
#  {'name': 'nextbike Ostrava',
#   'id': 'nextbike-ostrava',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ostrava'},
#  {'name': 'nextbike Ostrava',
#   'id': 'nextbike-ostrava-hlucin',
#   'company': ['Nextbike GmbH'],
#   'location': 'Hlučín'},
#  {'name': 'nextbike Ostrava',
#   'id': 'nextbike-ostrava-vresina',
#   'company': ['Nextbike GmbH'],
#   'location': 'Vřesina'},
#  {'name': 'Luboński Rower Miejski Poland',
#   'id': 'ski-rower-miejski-lubon',
#   'company': ['Nextbike GmbH'],
#   'location': 'Luboń'},
#  {'name': 'ibizi',
#   'id': 'ibizi-ibiza-city',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ibiza-City'},
#  {'name': 'sprintRAD',
#   'id': 'sprintrad',
#   'company': ['Nextbike GmbH'],
#   'location': 'Hannover'},
#  {'name': 'Komornicki System Rowerowy Poland',
#   'id': 'komornicki-system-rowerowy-komorniki',
#   'company': ['Nextbike GmbH'],
#   'location': 'Komorniki'},
#  {'name': 'nextbike Havířov',
#   'id': 'nextbike-havirov',
#   'company': ['Nextbike GmbH'],
#   'location': 'Havířov'},
#  {'name': 'nextbike Berounsko',
#   'id': 'nextbike-berounsko',
#   'company': ['Nextbike GmbH'],
#   'location': 'Berounsko'},
#  {'name': 'Graben - ready4green',
#   'id': 'ready4green-graben',
#   'company': ['Nextbike GmbH'],
#   'location': 'Graben'},
#  {'name': 'Oleski Rower Miejski Poland',
#   'id': 'oleski-rower-miejski-olesno',
#   'company': ['Nextbike GmbH'],
#   'location': 'Olesno'},
#  {'name': 'Styr & Ställ (Sweden, Göteborg)',
#   'id': 'styr-staell-goeteborg',
#   'company': ['Nextbike GmbH'],
#   'location': 'Göteborg'},
#  {'name': 'Nibelungen-Bike',
#   'id': 'nibelungen-bike-braunschweig',
#   'company': ['Nextbike GmbH'],
#   'location': 'Braunschweig'},
#  {'name': 'nextbike Brno',
#   'id': 'nextbike-brno',
#   'company': ['Nextbike GmbH'],
#   'location': 'Brno'},
#  {'name': 'nextbike Brno',
#   'id': 'nextbike-brno-kurim',
#   'company': ['Nextbike GmbH'],
#   'location': 'Kuřim'},
#  {'name': 'nextbike Praha',
#   'id': 'nextbike-praha',
#   'company': ['Nextbike GmbH'],
#   'location': 'Praha'},
#  {'name': 'nextbike Praha',
#   'id': 'nextbike-praha-ricany',
#   'company': ['Nextbike GmbH'],
#   'location': 'Říčany'},
#  {'name': 'nextbike Olomouc',
#   'id': 'nextbike-olomouc',
#   'company': ['Nextbike GmbH'],
#   'location': 'Olomouc'},
#  {'name': 'nextbike Kladno',
#   'id': 'nextbike-kladno',
#   'company': ['Nextbike GmbH'],
#   'location': 'Kladno'},
#  {'name': 'nextbike Opava',
#   'id': 'nextbike-opava',
#   'company': ['Nextbike GmbH'],
#   'location': 'Opava'},
#  {'name': 'meinSiggi',
#   'id': 'nextbike-bielefeld',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bielefeld'},
#  {'name': 'YOY - San Luis Potosi',
#   'id': 'yoy-san-luis-potosi',
#   'company': ['Nextbike GmbH'],
#   'location': 'San Luis Potosi'},
#  {'name': 'YOY - San Luis Potosi',
#   'id': 'yoy-san-luis-potosi-cancun',
#   'company': ['Nextbike GmbH'],
#   'location': 'Cancún'},
#  {'name': 'Bergisches e-Bike',
#   'id': 'bergisches-e-bike',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bergisches e-Bike'},
#  {'name': 'nextbike Pardubice',
#   'id': 'nextbike-pardubice',
#   'company': ['Nextbike GmbH'],
#   'location': 'Pardubice'},
#  {'name': 'nextbike Hradec Králové',
#   'id': 'nextbike-hradec-kralove',
#   'company': ['Nextbike GmbH'],
#   'location': 'Hradec Králové'},
#  {'name': 'nextbike Mladoboleslavsko',
#   'id': 'nextbike-mladoboleslavsko-mlada-boleslav',
#   'company': ['Nextbike GmbH'],
#   'location': 'Mladá Boleslav'},
#  {'name': 'nextbike Mladoboleslavsko',
#   'id': 'nextbike-mladoboleslavsko-mnichovo-hradiste',
#   'company': ['Nextbike GmbH'],
#   'location': 'Mnichovo Hradiště'},
#  {'name': 'Oeynrad',
#   'id': 'oeynrad-bad-oeynhausen',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bad Oeynhausen'},
#  {'name': 'RSVG-Bike',
#   'id': 'rsvg-bike',
#   'company': ['Nextbike GmbH'],
#   'location': 'RSVG'},
#  {'name': 'city bike Linz',
#   'id': 'citybikelinz',
#   'company': ['Nextbike GmbH'],
#   'location': 'Linz'},
#  {'name': 'Drobeta Velopark',
#   'id': 'velopark-drobeta',
#   'company': ['Nextbike GmbH'],
#   'location': 'Drobeta'},
#  {'name': 'Nomago Bikes - GO2GO',
#   'id': 'nomago-gorica',
#   'company': ['Nextbike GmbH'],
#   'location': 'Nova Gorica'},
#  {'name': 'Saturn',
#   'id': 'saturn',
#   'company': ['Nextbike GmbH'],
#   'location': 'Saturn'},
#  {'name': 'nextbike Frýdek-Místek',
#   'id': 'nextbike-frydek-mistek',
#   'company': ['Nextbike GmbH'],
#   'location': 'Frýdek-Místek'},
#  {'name': 'nextbike Uherské Hradiště',
#   'id': 'nextbike-uherske-hradiste',
#   'company': ['Nextbike GmbH'],
#   'location': 'Uherské Hradiště'},
#  {'name': 'nextbike Zlín',
#   'id': 'nextbike-zlin',
#   'company': ['Nextbike GmbH'],
#   'location': 'Zlín'},
#  {'name': 'nextbike Krnov',
#   'id': 'nextbike-krnov',
#   'company': ['Nextbike GmbH'],
#   'location': 'Krnov'},
#  {'name': 'Eifel e-Bike',
#   'id': 'eifel',
#   'company': ['Nextbike GmbH'],
#   'location': 'Eifel e-Bike'},
#  {'name': 'nextbike Rychnovsko',
#   'id': 'nextbike-rychnovsko',
#   'company': ['Nextbike GmbH'],
#   'location': 'Rychnovsko'},
#  {'name': 'nextbike Písek',
#   'id': 'nextbike-pisek',
#   'company': ['Nextbike GmbH'],
#   'location': 'Písek'},
#  {'name': 'nextbike Jihlava',
#   'id': 'nextbike-jihlava',
#   'company': ['Nextbike GmbH'],
#   'location': 'Jihlava'},
#  {'name': 'Nomago Bikes - ZANAPREJ',
#   'id': 'nomago-zanaprej',
#   'company': ['Nextbike GmbH'],
#   'location': 'Zagorje ob Savi'},
#  {'name': 'Rower Powiatowy Sokołów Podlaski',
#   'id': 'rower-powiatowy-sokolow-podlaski',
#   'company': ['Nextbike GmbH'],
#   'location': 'Sokołów Podlaski'},
#  {'name': 'nextbike Bergamo',
#   'id': 'nextbike-bergamo',
#   'company': ['Nextbike GmbH'],
#   'location': 'Bergamo'},
#  {'name': 'eMobi (Croatia)',
#   'id': 'emobi-osijek',
#   'company': ['Nextbike GmbH'],
#   'location': 'Osijek'},
#  {'name': 'ARVAL',
#   'id': 'arval-scandicci',
#   'company': ['Nextbike GmbH'],
#   'location': 'Scandicci'},
#  {'name': 'OLi-Bike',
#   'id': 'nextbike-oldenburg',
#   'company': ['Bremer Tageszeitungen AG'],
#   'location': 'Oldenburg'},
#  {'name': 'BBK Klimabizi',
#   'id': 'nextbike-urdaibai',
#   'company': ['Nextbike GmbH'],
#   'location': 'Urdaibai'},
#  {'name': 'MV-Rad',
#   'id': 'mvrad-hq',
#   'company': ['Nextbike GmbH'],
#   'location': 'MV-Rad'},
#  {'name': 'MV-Rad',
#   'id': 'mvrad-anklam',
#   'company': ['Nextbike GmbH'],
#   'location': 'Anklam'},
#  {'name': 'StadtRad Greifswald',
#   'id': 'greifswald',
#   'company': ['Nextbike GmbH'],
#   'location': 'Greifswald (StadtRad)'},
#  {'name': 'nextbike Dvůr Králové',
#   'id': 'nextbike-dvur-kralove',
#   'company': ['Nextbike GmbH'],
#   'location': 'Dvůr Králové'},
#  {'name': 'VVT REGIORAD Tirol',
#   'id': 'vvtregiorad-kufstein',
#   'company': ['Nextbike GmbH'],
#   'location': 'Kufstein'},
#  {'name': 'VVT REGIORAD Tirol',
#   'id': 'vvtregiorad-ellmau',
#   'company': ['Nextbike GmbH'],
#   'location': 'Ellmau'},
#  {'name': 'Chełmski Rower',
#   'id': 'ski-rower-chelm',
#   'company': ['Nextbike GmbH'],
#   'location': 'Chełm'},
#  {'name': 'nextbike Vrchlabí',
#   'id': 'nextbike-vrchlabi',
#   'company': ['Nextbike GmbH'],
#   'location': 'Vrchlabí'},
#  {'name': 'WinsenRad',
#   'id': 'winsenrad',
#   'company': ['Nextbike GmbH'],
#   'location': 'Winsen (Luhe)'},
#  {'name': 'ŁoKeR - Łomża',
#   'id': 'loker-lomza',
#   'company': ['Nextbike GmbH'],
#   'location': 'Łomża'},
#  {'name': 'Nomago Bikes - KRANJSKA GORA',
#   'id': 'nomago-kranjska-gora',
#   'company': ['Nextbike GmbH'],
#   'location': 'Kranjska Gora'},
#  {'name': 'Nomago Bikes - PORTOROZ',
#   'id': 'nomago-portoroz',
#   'company': ['Nextbike GmbH'],
#   'location': 'Portorož'},
#  {'name': 'VRN',
#   'id': 'vrn-landau',
#   'company': ['Nextbike GmbH'],
#   'location': 'Landau in der Pfalz'},
#  {'name': 'Velocity',
#   'id': 'velocity-aachen',
#   'company': None,
#   'location': 'Aachen'},
#  {'name': 'àVélo',
#   'id': 'avelo-quebec',
#   'company': None,
#   'location': 'Québec'},
#  {'name': 'Accès Vélo',
#   'id': 'acces-velo-saguenay',
#   'company': None,
#   'location': 'Saguenay'}]

# %%
#checking the lenths
len(networks)
# Out:
# 614

# %%
#imporing the pandas to get the data set!
import pandas as pd

# %%
#coverting list(networks) to DataFrame to get the final data set!
df = pd.DataFrame(networks)

# %%
# to get final output, a variable named 'df' has been called
df
# Out:
#                         name                   id  \
# 0                   Velobike      velobike-moscow
# 1                   Bysykkel      baerum-bysykkel
# 2                 Bicincittà     bicincitta-siena
# 3                 Cyclopolis  cyclopolis-maroussi
# 4                 Cycle Hire    cycle-hire-slough
# ..                       ...                  ...
# 609  Nomago Bikes - PORTOROZ      nomago-portoroz
# 610                      VRN           vrn-landau
# 611                 Velocity      velocity-aachen
# 612                    àVélo         avelo-quebec
# 613               Accès Vélo  acces-velo-saguenay
#
#                                        company             location
# 0                             [ЗАО «СитиБайк»]               Moscow
# 1               [Urban Infrastructure Partner]                Bærum
# 2                          [Comunicare S.r.l.]                Siena
# 3                         [Cyclopolis Systems]             Maroussi
# 4    [Groundwork, Slough Borough Council, ITS]               Slough
# ..                                         ...                  ...
# 609                            [Nextbike GmbH]             Portorož
# 610                            [Nextbike GmbH]  Landau in der Pfalz
# 611                                       None               Aachen
# 612                                       None               Québec
# 613                                       None             Saguenay
#
# [614 rows x 4 columns]

# %%
# coverting the output to csv without indexing
df.to_csv('Project_on_GET_01.csv',index = False)
